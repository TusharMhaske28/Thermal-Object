# %% [markdown]
# <a href="https://colab.research.google.com/github/TusharMhaske28/Thermal-Object/blob/master/Yolov4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! unzip /content/drive/'My Drive'/darknet-master.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08335.txt
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08336.jpeg
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08336.txt
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08337.jpeg
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08337.txt
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08338.jpeg
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08338.txt
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08339.jpeg
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08339.txt
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08340.jpeg
#   inflating: /content/darknet-master/build/darknet/x64/data/obj/FLIR_08340.txt
# ...

# %%
# %cd /content/darknet-master/
# Out:
# /content/darknet-master

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:910:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1391:14: warning: unused variable ‘buff’ [-Wunused-variable]
#          char buff[100];
#               ^~~~
# ...

# %%
mv /content/darknet-master/darknet /content/darknet-master/build/darknet/x64/

# %%
# %cd /content/darknet-master/build/darknet/x64
# Out:
# /content/darknet-master/build/darknet/x64

# %%
  ! ./darknet
# Out:
# usage: ./darknet <function>

# %%
! ./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_1000.weights -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# yolo-obj
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# mini_batch = 2, batch = 128, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    3 route  1 		                           ->  304 x 304 x  64
#    4 conv     64       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  64 0.757 BF
#    5 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    6 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
# ...

# %%
# !cp /content/darknet-master/build/darknet/x64/backup/yolo-obj_last.weights /content/darknet-master/build/darknet/x64

# %%
! ./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_last.weights -dont_show

# %%
# !cp /content/darknet-master/build/darknet/x64/backup/yolo-obj_last.weights /content/darknet-master/build/darknet/x64

# %%
! ./darknet detector train data/obj.data yolo-obj.cfg yolo-obj_last.weights -dont_show

# %%
from google.colab import files
files.download('/content/darknet-master/build/darknet/x64/backup/yolo-obj_last.weights')

# %%
# !cp /content/drive/'My Drive'/yolo-obj_1000.weights  /content/darknet-master/build/darknet/x64
